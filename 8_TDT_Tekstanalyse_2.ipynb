# %% [markdown]
# # Tekstanalyse 2: Named entities regognition (NER) og Parts of Speech Tagging (POS) med SpaCy
# ***
# ***
# Keywords: `context manager`, `named entity recognition`, `NER`, `parts of speech tagging`, `POS`, `WordCloud`
#
# Nye Python-udtryk:  `with`, `.set()`, `.sorted()`, `.join()`, `WordCloud()`
# ***
# ***
# I det følgende skal vi se nærmere på NLP-pakken `SpaCy`, der er indeholder effektive og kraftfulde redskaber til tekstanalyse. I modsætning til `NLTK`-pakken, der er regelbaseret, er SpaCy baseret på maskinlæring, hvilket bl.a. betyder, at den virker godt på dansk, for sprogmodulet også er trænet på danske tekster.
#
# SpaCy kan mange forskellige ting. Vi lægger ud med at kigge på **Named Entity Recognition** (NER) og **Parts of Speech Tagging**.
#
# Nogle af elementerne vil være repetition af elementer fra tidligere notebooks.
#
# Hvis der er kode sekvenser eller udtryk i ikke forstår, er det altid en god idé at bruge Google. Det kan give svar på det meste.
#
# ### Husk at kommentere eksemplerne, så I også kan læse og forstå dem senere

# %% [markdown]
# # 1. Forberedelse

# %% [markdown]
# ### Dependencies
# Som altid begynder vi med at importere de nødvendige `libraries`. Udover `os`, `Numpy` og `Pandas` skal vi også bruge `matplotlib` og `nltk`.

# %%
import os                       # os tillader os bl.a. at finde filplaceringer på computeren
import numpy as np              # Numpy leverer noget af matematikken, der ligger under Pandas 
import pandas as pd             # Pandas tillader os at importere, oprette og manipulere data frames
import matplotlib.pyplot as plt # Importerer underbiblioteket pyplot fra pakken matplotlib
from nltk.text import Text      # nltk indholder mange forskellige funktioner, der kan bruges til tekstanalyse

# %% [markdown]
# Herudover skal vi også importere `SpaCy`. Når vi bruger spacy, skal vi udover at importere modulet, også loade en sprogmodel. Der er tre modeller at vælge mellem: `da_core_news_sm`, `da_core_news_md`, `da_core_news_lg`, en lille (sm), en mellem (md) og en stor (lg). Størrelsen angiver, hvor stort et korpus modellen er blevet trænet på.
#
# Hvis I ikke allerede har gjort det skal, skal I, første gang I bruger SpaCy, downloade de modeller, I vil bruge. I kan enten gøre det fra kommandoprompten eller direkte fra jeres Notebook. Hvis i gør det fra Notebok'en skal I sætte `!` foran kommandoen (se nedenfor). Det angiver at der er en command line-kommando. Hvis I åbner kopmmandoprompten, skal I bruge samme kommando, men undlade `!`.

# %%
# !python -m spacy download da_core_news_sm
# Out:
# Collecting da-core-news-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/da_core_news_sm-3.2.0/da_core_news_sm-3.2.0-py3-none-any.whl (19.1 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\h_joa\anaconda3\lib\site-packages (from da-core-news-sm==3.2.0) (3.2.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (8.0.15)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (0.9.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2.0.6)
# Requirement already satisfied: setuptools in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (58.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (0.7.7)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (1.20.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2.26.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (1.0.2)
# Requirement already satisfied: jinja2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (3.0.9)
# Requirement already satisfied: click<8.1.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (8.0.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (21.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2.4.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (0.6.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (3.0.6)
# Requirement already satisfied: colorama in c:\users\h_joa\anaconda3\lib\site-packages (from click<8.1.0->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\h_joa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\h_joa\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->da-core-news-sm==3.2.0) (1.1.1)
# Installing collected packages: da-core-news-sm
# Successfully installed da-core-news-sm-3.2.0
# [+] Download and installation successful
# You can now load the package via spacy.load('da_core_news_sm')

# %%
# !python -m spacy download da_core_news_md
# Out:
# Collecting da-core-news-md==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/da_core_news_md-3.2.0/da_core_news_md-3.2.0-py3-none-any.whl (48.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\h_joa\anaconda3\lib\site-packages (from da-core-news-md==3.2.0) (3.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (0.7.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (21.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (0.9.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (1.20.3)
# Requirement already satisfied: click<8.1.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (8.0.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (4.62.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (3.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2.0.7)
# Requirement already satisfied: jinja2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2.11.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (0.4.1)
# Requirement already satisfied: setuptools in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (58.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (3.3.0)
# Requirement already satisfied: colorama in c:\users\h_joa\anaconda3\lib\site-packages (from click<8.1.0->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\h_joa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\h_joa\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->da-core-news-md==3.2.0) (1.1.1)
# Installing collected packages: da-core-news-md
# Successfully installed da-core-news-md-3.2.0
# [+] Download and installation successful
# You can now load the package via spacy.load('da_core_news_md')

# %%
# !python -m spacy download da_core_news_lg
# Out:
# Collecting da-core-news-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/da_core_news_lg-3.2.0/da_core_news_lg-3.2.0-py3-none-any.whl (573.8 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\h_joa\anaconda3\lib\site-packages (from da-core-news-lg==3.2.0) (3.2.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (8.0.15)
# Requirement already satisfied: setuptools in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (58.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (1.20.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2.4.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (0.9.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (21.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2.26.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (0.7.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (3.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (0.4.1)
# Requirement already satisfied: jinja2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (4.62.3)
# Requirement already satisfied: click<8.1.0 in c:\users\h_joa\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (8.0.3)
# Requirement already satisfied: colorama in c:\users\h_joa\anaconda3\lib\site-packages (from click<8.1.0->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\h_joa\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\h_joa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\h_joa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (1.26.7)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\h_joa\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->da-core-news-lg==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('da_core_news_lg')

# %% [markdown]
# **Importér** SpaCy og **load** den store danske sprog-model. Den kører derfor lidt langsommere end de andre, men er til gengæld mere præcis. Skal man arbejde med meget store tekstmængder, kan det være en idé at bruge en mindre model. Det er en afvejning af regnekraft/tid mod præcision.

# %%
import spacy

# %%
nlp = spacy.load("da_core_news_lg")

# %% [markdown]
# ### Import af tekster
# I denne notebook skal vi arbejde med seks forskellige nytårstaler. To af Mette Frederiksen, to af Lars Løkke Rasmussen og to af Helle Thorning Schmidt. **Placér** de downloadede `.txt`-filer i en mappe i den mappe, hvori i har gemt jeres script.

# %% [markdown]
# #### Context manager
# Der er forskellige måder at åbne filer på. Nedenfor finder I et eksempel på en såkaldt `context manager`. En af fordelene ved at bruge en context-manager er, at den automatisk lukker filerne igen efter de er blevet indlæst.
#
# Kodesekvensen begynder med et `for loop`, fordi vi skal åbne seks forskellige filer. Herefter følger context-manageren, der læses 'brug kommandoen 'open' til at åbne den angivne fil og gem den under variabelnavnet 'f' (f for fil er standard-notation, men det er en variabel, så navnet er valgfrit)'.
#
# Herefter tilføjer vi talerne til listen 'Taler'. **Bemærk** at rensning foregår i samme ombæring med `.replace()`. Teksten i .txt-filerne er allerede nogenlunde rensede, og det er derfor ikke nødvendigt at bruge rense-funktionerne. Denne måde virker bedst, hvis det kun er få ting, der skal gøres. Er rensningen mere omfattende, er det mere overskueligt, at definere en pipeline-funktion.

# %%
taler = [] # opretter tom liste

path = os.path.join("Taler") # bruges for at undgå mac/pc-problemerne med absolutte stinavne

for fil in os.scandir(path): # for-loop
    with open (fil, encoding = "utf8") as f: # context manager
        taler.append(f.read().replace("\n"," ").replace("*"," ")) # tilføj renset tekst til liste

# %% [markdown]
# For overskuelighedens skyld, lægger vi ud med at afprøve SpaCy på en enkelt tale. Vi gemmer talen under variabel-navnet 'tale_1'.
#
# **Bemærk** notationen `taler[0]`. **Hvad** betyder det, og **hvordan** læses det?

# %%
tale_1 = taler[0]

# %% [markdown]
# # SpaCy

# %% [markdown]
# Vi har allerede importeret `SpaCy` og load'et den store danske sprogmodel. Modellen blev gemt under navnet `nlp`. Det er standardnotation, men betegnelsen er valgfri, og I kan ændre det, hvis det er nødvendigt, fx hvis I har load'et flere forskellige modeller.
#
# Bag navnet 'nlp' gemmer der sig nu en masse funktionalitet, på samme måde som vi tidligere har pakket funktionalitet i vores pipeline-funktioner. Når I anvender 'nlp' på en tekst, gør den derfor mange ting på en gang, og outputtet, som vi gemmer under navnet 'doc1' er et komplekst objekt, der udover teksten indholder en masse tags og meta-data.

# %%
doc1 = nlp(tale_1)

# %% [markdown]
# Vi har ikke umiddelbart adgang til metainformationen. Prøv at taste `doc1` og `print(doc1)` i feltet nedenfor, og **diskutér** hvad I ser.

# %%
doc1
# Out:
# HTS_2012  Godaften.  For tre måneder siden fik Danmark en ny regering. En regering, som er trådt til i en krisetid. Og som vil tage fat på de alvorlige problemer, Danmark står med.  Vores mål er at bringe Danmark sikkert gennem krisen og ud på den anden side med vores velstand, ordentlighed og omsorg for hinanden i behold.  Det bliver ikke nemt. Men vi kan hvis vi vil.  Det nye år – 2012 – bliver ikke året, hvor vi kommer fri af problemerne. Det må vi allerede se i øjnene nu.  Men med fælles hjælp kan det blive året, hvor vi med seje skridt vender udviklingen.  Generation efter generation har vi skabt fremskridt for almindelige mennesker. Og vi har insisteret på, at alle skulle med. På den måde er Danmark blevet et fantastisk land.  Min mormor blev født i år 1900. Da hun var 15 år, fik kvinder og tjenestefolk stemmeret. Demokratiet blev bredt ud til almindelige danskere.  Min mor blev født i 1937. Mens hun voksede op, kom Danmark fri af krigen og rationeringsmærkerne, og efterhånden fik mange del i de goder, der før kun var for de få. Telefoner, appelsiner og flæskesteg på søndagsbordet.  Jeg blev født i 1966.  Da jeg voksede op, strømmede kvinderne ud på arbejdsmarkedet. Danmark fik børnehaver, plejehjem og uddannelser til de mange. Og danskerne fik nye muligheder. I min årgang blev vi ikke født til at følge en bestemt livsbane. Vi fik større frihed til selv at vælge, end nogen generation før os.  Når jeg i dag ser på vores unge, ser jeg en generation, som – hvis de får lov - til fulde forstår at bruge mulighederne. I griber verden. Og ja, I kommer også fra alle dele af verden. Unge med en anden etnisk baggrund er med til skabe et samfund, hvor mangfoldigheden bliver større, uden at Danmark bliver mindre.  Fra generation til generation – min mormors, min mors, min egen – er Danmark blevet et bedre land at leve i. Et land, vi kan være stolte af.  Og vi skal blive ved med at skabe fremgang for vores børn. Det er et rimeligt krav at stille til os selv.  Men krisen har gjort det vanskeligere. Og jeg vil sige det meget klart i aften.  De fede år ligger bag os. Vi skal forberede os på nogle magre år.  Den kommende tid vil kræve meget af os.          Meget er sket på kort tid.  Kan I huske, hvordan det var for bare fire-fem år siden? Dengang kunne man nærmest gå ind fra gaden og få et job. Og man kunne dårligt gå ind i en bank uden at komme ud med et lån.  Nu har mange – særligt de unge - svært ved at finde arbejde. Virksomheder har svært ved at sælge deres varer. Utryghed og bekymring for fremtiden er blevet en del af mange familiers hverdag.  Skiftet fra gode til dårlige tider blev forstærket af begivenheder ude i verden. Man førte en kortsigtet og slap økonomisk politik. Nogle finansfolk jagtede den hurtige gevinst. Der blev flyttet rundt på investeringer, som om det var matadorpenge.  Det var det ikke. Det var menneskers arbejde, hverdag og opsparing.  Også herhjemme var der et vist overmod. Mange handlede, som om de gode tider bare ville fortsætte og fortsætte. Forbruget voksede over evne. Og boligpriserne tog på himmelflugt.  Der blev givet skattelettelser, som der dybest set ikke var råd til. Og man forsømte at ruste Danmark godt nok til dårligere tider. Der var ikke styr på økonomien.  Derfor får vi nu et underskud på de offentlige finanser på omkring 100 milliarder kroner. Ja, måske bliver det endnu større.  Det er svimlende mange penge.  Underskuddet betyder, at vi betaler velfærd med penge, vi ikke har.  Det går ikke i længden. Det siger sig selv.  Og det går heller ikke, at Danmark bliver ved med at miste konkurrencekraft. For så flytter virksomheder og job ud af landet.  Danske virksomheder er nogle af de mest opfindsomme og ansvarsfulde i verden. Vi er et land, hvor små familievirksomheder vokser sig store og bliver blandt verdens førende. Vi er et land, hvor lønmodtagere og arbejdsgivere har et helt særligt tillidsfuldt samarbejde. Et samarbejde, som vækker international opsigt.  Men når man ikke har investeret nok i  ...

# %% [markdown]
# # 2. Named Entity Regonition

# %% [markdown]
# Det første vi skal se på er `named entity recognition`, som er en funktion, der gør det muligt at genkende personer, organisationer, steder mm.
#
# For at hente informationen ud af vore `doc`-objekt, skal vi bruge `.ents`-kommandoen, der er nemmest at arbejde med, hvis vi gemmer informationen på en liste.
#
# **Afprøv** sekvensen nedenfor. **Læs** koden og **diskutér**, hvad de enkelte dele betyder.

# %%
ents1 = list(doc1.ents)

# %% [markdown]
# Hvis vi bare printer indholdet af variablen 'ents1', får vi blot en ordliste. Vi er derfor nødt til specifikt at bede om de enkelte elementer vha. `.text` og `.label_`-kopmmandoerne.
#
# **Afprøv** sekvensen nedenfor. **Læs** koden og **diskutér**, hvad de enkelte dele betyder.

# %%
for w in ents1:
    print(w.text,w.label_)
# Out:
# HTS_2012 ORG
# Danmark LOC
# Danmark LOC
# Danmark LOC
# Danmark LOC
# Demokratiet MISC
# danskere MISC
# Danmark LOC
# Danmark LOC
# danskerne MISC
# Danmark LOC
# Danmark LOC
# Danmark LOC
# Danmark LOC
# Danske MISC
# Danmark LOC
# Danmark LOC
# danske MISC
# Europa LOC
# europæerne MISC
# danske MISC
# Danmark LOC
# Danmark LOC
# danskere MISC
# Danmark LOC
# danskere MISC
# Danmark LOC
# dansk MISC
# Aalborg LOC
# Søren PER
# Søren PER
# Midt- LOC
# Nordjylland LOC
# Danmark LOC
# danskere MISC
# danske MISC
# Afghanistan LOC
# Danmark LOC
# Afghanistan LOC
# Danmarks LOC
# Afghanistan LOC
# Libyen LOC
# Danmark LOC
# arabiske MISC
# Danmark LOC
# Danmark LOC
# Danmark LOC
# EU ORG
# Danmark LOC
# EU ORG
# europæiske MISC
# Europa LOC
# Europa LOC
# Europa LOC
# Danmarks LOC
# danskernes MISC
# Europa LOC
# Danmark LOC
# Danmark LOC

# %% [markdown]
# Hvis I er usikre på, hvad et SpaCy-tag betyder kan I altid bruge `spacy.explain()`, fx:

# %%
spacy.explain("LOC")
# Out:
# 'Non-GPE locations, mountain ranges, bodies of water'

# %% [markdown]
# ## Personer
# På listen ovenfor har vi en komplet oversigt over de ord, som SpaCy har vurderet betegner personer, steder osv. Når I skal bruge det analytiske, skal i naturligvis tjekke, om der er fejl. SpaCy performer godt, men der er pt. ingen modeller, der kan levere 100% præcision.
#
# Hvis vi vil udtrække en liste over personer, kan vi bruge `.label_` til at sortere med.
#
# I eksemplet nedenfor bruger vi `list comprehension`til at lave en liste, samt `.set()` til at slette dubletter, og `.sorted()` til at sortere outputtet. Et `set` (en mængde) er karakteriseret ved, at den kun indholde ét eksemplar af hvert element. Når vi transformerer en liste til en mængde, sletter vi derfor automatisk alle ord-dubletter. Kommandoen `.sorted()`transformerer herefter mængden til en sorteret liste.
#
# Som vi så sidst fungerer `list comprehension` lidt som et `for loop`. Vi laver altså en liste af de tekstelementer (.text)fra listen 'ents1', der har et label (.label_), der er lig med "PER". Herefter slettes dubletter, og listen sorteres alfabetisk.
#
# **Afprøv** kode sekvensen nedenfor. **Læs** koden og **diskutér** hvad de enkelte betyder.

# %%
personer = sorted(set([t.text for t in ents1 if t.label_ == "PER"]))

# %% [markdown]
# **Print** listen for at se resultatet.

# %%
print(personer)
# Out:
# ['Søren']

# %% [markdown]
# # Opgave 1
# Lav tilsvarende lister, hvor i sorterer efter `"LOC"` (steder) og `"MISC"` (miscellaneous/diverse).

# %% [markdown]
# ## Steder

# %% [markdown]
# ## Diverse (miscellaneous)

# %% [markdown]
# # Opgave 2
# Vælg en tale af henholdsvis Lars Løkke Rasmussen og Mette Frederiksen og lav for hver af de to taler en NER-analyse samt lister med personer, steder og diverse.
#
# **Husk** at I allerede har indlæst alle taler under variabelnavnet `taler`
#
# **Husk også** at give variablerne nye navne, fx `personer_LLR` og `personer_MF`, så I ikke overskriver de lister, I allerede har lavet!

# %% [markdown]
# #### Lars Løkke rasmussen

# %% [markdown]
# #### Mette Frederiksen

# %% [markdown]
# # Opgave 3
# **Sammenlign** listerne for de tre taler. **Diskutér** forskelle og ligheder i indholdet af talerne. **Hvordan** kan vi bruge denne information til at karakterisere teksterne.

# %% [markdown]
# # 3. Parts of Speech Tagging (POS)

# %% [markdown]
# Det næste vi skal se på er SpaCy's POS-modul. `Parts of Speech Tagging` er en funktion, der gør det muligt at opmærke alle ord med ordklasse-tags.
#
# For at hente informationen ud af vore doc-objekt, skal vi bruge `.sents`-kommandoen. Der er ligesom sidst nemmest at håndtere, hvis vi gemmer informationen på en liste.
#
# **Afprøv** sekvensen nedenfor. **Læs** koden og **diskutér** hvad de enkelte dele betyder.

# %%
sents1 = list(doc1.sents)[1:]

# %% [markdown]
# **Hvad** er konsekvensen af at tilføje `[1:]`. **Lav** eventuelt en liste, hvor I udlader dette. Sammenlign de to lister. **Hvad** er forskellen?

# %%
sents0 = list(doc1.sents)

# %%
print(sents0)
# Out:
# [HTS_2012  Godaften.,  For tre måneder siden fik Danmark en ny regering., En regering, som er trådt til i en krisetid., Og som vil tage fat på de alvorlige problemer, Danmark står med.,  Vores mål er at bringe Danmark sikkert gennem krisen og ud på den anden side med vores velstand, ordentlighed og omsorg for hinanden i behold.,  , Det bliver ikke nemt., Men vi kan hvis vi vil.,  Det nye år – 2012 – bliver ikke året, hvor vi kommer fri af problemerne., Det må vi allerede se i øjnene nu.,  Men med fælles hjælp kan det blive året, hvor vi med seje skridt vender udviklingen.,  Generation efter generation har vi skabt fremskridt for almindelige mennesker., Og vi har insisteret på, at alle skulle med., På den måde er Danmark blevet et fantastisk land.,  Min mormor blev født i år 1900., Da hun var 15 år, fik kvinder og tjenestefolk stemmeret., Demokratiet blev bredt ud til almindelige danskere.,  Min mor blev født i 1937., Mens hun voksede op, kom Danmark fri af krigen og rationeringsmærkerne, og efterhånden fik mange del i de goder, der før kun var for de få., Telefoner, appelsiner og flæskesteg på søndagsbordet.,  Jeg blev født i 1966.,  Da jeg voksede op, strømmede kvinderne ud på arbejdsmarkedet., Danmark fik børnehaver, plejehjem og uddannelser til de mange., Og danskerne fik nye muligheder., I min årgang blev vi ikke født til at følge en bestemt livsbane., Vi fik større frihed til selv at vælge, end nogen generation før os.,  , Når jeg i dag ser på vores unge, ser jeg en generation, som – hvis de får lov - til fulde forstår at bruge mulighederne., I griber verden., Og ja, I kommer også fra alle dele af verden., Unge med en anden etnisk baggrund er med til skabe et samfund, hvor mangfoldigheden bliver større, uden at Danmark bliver mindre.,  Fra generation til generation – min mormors, min mors, min egen – er Danmark blevet et bedre land at leve i., Et land, vi kan være stolte af.,  Og vi skal blive ved med at skabe fremgang for vores børn., Det er et rimeligt krav at stille til os selv.,  Men krisen har gjort det vanskeligere., Og jeg vil sige det meget klart i aften.,  , De fede år ligger bag os., Vi skal forberede os på nogle magre år.,  Den kommende tid vil kræve meget af os.,          Meget er sket på kort tid.,  Kan I huske, hvordan det var for bare fire-fem år siden?, Dengang kunne man nærmest gå ind fra gaden og få et job., Og man kunne dårligt gå ind i en bank uden at komme ud med et lån.,  , Nu har mange – særligt de unge - svært ved at finde arbejde., Virksomheder har svært ved at sælge deres varer., Utryghed og bekymring for fremtiden er blevet en del af mange familiers hverdag.,  , Skiftet fra gode til dårlige tider blev forstærket af begivenheder ude i verden., Man førte en kortsigtet og slap økonomisk politik., Nogle finansfolk jagtede den hurtige gevinst., Der blev flyttet rundt på investeringer, som om det var matadorpenge.,  , Det var det ikke., Det var menneskers arbejde, hverdag og opsparing.,  Også herhjemme var der et vist overmod., Mange handlede, som om de gode tider bare ville fortsætte og fortsætte., Forbruget voksede over evne., Og boligpriserne tog på himmelflugt.,  Der blev givet skattelettelser, som der dybest set ikke var råd til., Og man forsømte at ruste Danmark godt nok til dårligere tider., Der var ikke styr på økonomien.,  , Derfor får vi nu et underskud på de offentlige finanser på omkring 100 milliarder kroner., Ja, måske bliver det endnu større.,  , Det er svimlende mange penge.,  , Underskuddet betyder, at vi betaler velfærd med penge, vi ikke har.,  , Det går ikke i længden., Det siger sig selv.,  Og det går heller ikke, at Danmark bliver ved med at miste konkurrencekraft., For så flytter virksomheder og job ud af landet.,  Danske virksomheder er nogle af de mest opfindsomme og ansvarsfulde i verden., Vi er et land, hvor små familievirksomheder vokser sig store og bliver blandt verdens førende., Vi er et land, hvor lønmodtagere og arbejdsgivere har et helt særligt tillidsfuldt samarbejde ...

# %%
print(sents1)
# Out:
# [ For tre måneder siden fik Danmark en ny regering., En regering, som er trådt til i en krisetid., Og som vil tage fat på de alvorlige problemer, Danmark står med.,  Vores mål er at bringe Danmark sikkert gennem krisen og ud på den anden side med vores velstand, ordentlighed og omsorg for hinanden i behold.,  , Det bliver ikke nemt., Men vi kan hvis vi vil.,  Det nye år – 2012 – bliver ikke året, hvor vi kommer fri af problemerne., Det må vi allerede se i øjnene nu.,  Men med fælles hjælp kan det blive året, hvor vi med seje skridt vender udviklingen.,  Generation efter generation har vi skabt fremskridt for almindelige mennesker., Og vi har insisteret på, at alle skulle med., På den måde er Danmark blevet et fantastisk land.,  Min mormor blev født i år 1900., Da hun var 15 år, fik kvinder og tjenestefolk stemmeret., Demokratiet blev bredt ud til almindelige danskere.,  Min mor blev født i 1937., Mens hun voksede op, kom Danmark fri af krigen og rationeringsmærkerne, og efterhånden fik mange del i de goder, der før kun var for de få., Telefoner, appelsiner og flæskesteg på søndagsbordet.,  Jeg blev født i 1966.,  Da jeg voksede op, strømmede kvinderne ud på arbejdsmarkedet., Danmark fik børnehaver, plejehjem og uddannelser til de mange., Og danskerne fik nye muligheder., I min årgang blev vi ikke født til at følge en bestemt livsbane., Vi fik større frihed til selv at vælge, end nogen generation før os.,  , Når jeg i dag ser på vores unge, ser jeg en generation, som – hvis de får lov - til fulde forstår at bruge mulighederne., I griber verden., Og ja, I kommer også fra alle dele af verden., Unge med en anden etnisk baggrund er med til skabe et samfund, hvor mangfoldigheden bliver større, uden at Danmark bliver mindre.,  Fra generation til generation – min mormors, min mors, min egen – er Danmark blevet et bedre land at leve i., Et land, vi kan være stolte af.,  Og vi skal blive ved med at skabe fremgang for vores børn., Det er et rimeligt krav at stille til os selv.,  Men krisen har gjort det vanskeligere., Og jeg vil sige det meget klart i aften.,  , De fede år ligger bag os., Vi skal forberede os på nogle magre år.,  Den kommende tid vil kræve meget af os.,          Meget er sket på kort tid.,  Kan I huske, hvordan det var for bare fire-fem år siden?, Dengang kunne man nærmest gå ind fra gaden og få et job., Og man kunne dårligt gå ind i en bank uden at komme ud med et lån.,  , Nu har mange – særligt de unge - svært ved at finde arbejde., Virksomheder har svært ved at sælge deres varer., Utryghed og bekymring for fremtiden er blevet en del af mange familiers hverdag.,  , Skiftet fra gode til dårlige tider blev forstærket af begivenheder ude i verden., Man førte en kortsigtet og slap økonomisk politik., Nogle finansfolk jagtede den hurtige gevinst., Der blev flyttet rundt på investeringer, som om det var matadorpenge.,  , Det var det ikke., Det var menneskers arbejde, hverdag og opsparing.,  Også herhjemme var der et vist overmod., Mange handlede, som om de gode tider bare ville fortsætte og fortsætte., Forbruget voksede over evne., Og boligpriserne tog på himmelflugt.,  Der blev givet skattelettelser, som der dybest set ikke var råd til., Og man forsømte at ruste Danmark godt nok til dårligere tider., Der var ikke styr på økonomien.,  , Derfor får vi nu et underskud på de offentlige finanser på omkring 100 milliarder kroner., Ja, måske bliver det endnu større.,  , Det er svimlende mange penge.,  , Underskuddet betyder, at vi betaler velfærd med penge, vi ikke har.,  , Det går ikke i længden., Det siger sig selv.,  Og det går heller ikke, at Danmark bliver ved med at miste konkurrencekraft., For så flytter virksomheder og job ud af landet.,  Danske virksomheder er nogle af de mest opfindsomme og ansvarsfulde i verden., Vi er et land, hvor små familievirksomheder vokser sig store og bliver blandt verdens førende., Vi er et land, hvor lønmodtagere og arbejdsgivere har et helt særligt tillidsfuldt samarbejde., Et samarbejde, som ...

# %% [markdown]
# Som vi gjorde ovenfor, kan vi hente tekst og tag ud af listen vha. `.text`og `.pos_`.
#
# Kodesekvensen nedenfor giver os en komplet liste (og den er lang).
#
# **Afprøv** sekvensen nedenfor. **Læs** koden og **diskutér**, hvad de enkelte dele betyder.

# %%
for s in sents1:
    for w in s:
        print(w.text, w.pos_)
# Out:
#   SPACE
# For ADP
# tre NUM
# måneder NOUN
# siden ADV
# fik VERB
# Danmark PROPN
# en DET
# ny ADJ
# regering NOUN
# . PUNCT
# En DET
# regering NOUN
# , PUNCT
# som PRON
# er AUX
# trådt VERB
# til ADV
# i ADP
# en DET
# krisetid NOUN
# . PUNCT
# Og CCONJ
# som ADP
# vil AUX
# tage VERB
# fat ADV
# på ADP
# de DET
# alvorlige ADJ
# problemer NOUN
# , PUNCT
# Danmark PROPN
# står VERB
# med ADP
# . PUNCT
#   SPACE
# Vores DET
# mål NOUN
# er VERB
# at PART
# bringe VERB
# Danmark PROPN
# sikkert ADV
# gennem ADP
# krisen NOUN
# og CCONJ
# ud ADV
# på ADP
# den DET
# anden DET
# side NOUN
# med ADP
# vores DET
# velstand NOUN
# , PUNCT
# ordentlighed NOUN
# og CCONJ
# omsorg NOUN
# for ADP
# hinanden PRON
# i ADP
# behold NOUN
# . PUNCT
#   SPACE
# Det PRON
# bliver AUX
# ikke ADV
# nemt ADJ
# . PUNCT
# Men CCONJ
# vi PRON
# kan AUX
# hvis SCONJ
# vi PRON
# vil VERB
# . PUNCT
#   SPACE
# Det DET
# nye ADJ
# år NOUN
# – AUX
# 2012 NUM
# – PUNCT
# bliver AUX
# ikke ADV
# året NOUN
# , PUNCT
# hvor ADV
# vi PRON
# kommer VERB
# fri ADJ
# af ADP
# problemerne NOUN
# . PUNCT
# Det PRON
# må AUX
# vi PRON
# allerede ADV
# se VERB
# i ADP
# øjnene NOUN
# nu ADV
# . PUNCT
#   SPACE
# Men CCONJ
# med ADP
# fælles ADJ
# hjælp NOUN
# kan AUX
# det PRON
# blive AUX
# året NOUN
# , PUNCT
# hvor ADV
# vi PRON
# med ADP
# seje ADJ
# skridt NOUN
# vender VERB
# udviklingen NOUN
# . PUNCT
#   SPACE
# Generation NOUN
# efter ADP
# generation NOUN
# har AUX
# vi PRON
# skabt VERB
# fremskridt NOUN
# for ADP
# almindelige ADJ
# mennesker NOUN
# . PUNCT
# Og CCONJ
# vi PRON
# har AUX
# insisteret VERB
# på ADP
# , PUNCT
# at SCONJ
# alle ADJ
# skulle AUX
# med ADV
# . PUNCT
# På ADP
# den DET
# måde NOUN
# er AUX
# Danmark PROPN
# blevet AUX
# et DET
# fantastisk ADJ
# land NOUN
# . PUNCT
#   SPACE
# Min DET
# mormor NOUN
# blev AUX
# født VERB
# i ADP
# år NOUN
# 1900 NUM
# . PUNCT
# Da SCONJ
# hun PRON
# var AUX
# 15 NUM
# år NOUN
# , PUNCT
# fik VERB
# kvinder NOUN
# og CCONJ
# tjenestefolk NOUN
# stemmeret NOUN
# . PUNCT
# Demokratiet NOUN
# blev AUX
# bredt ADV
# ud ADV
# til ADP
# almindelige ADJ
# danskere NOUN
# . PUNCT
#   SPACE
# Min DET
# mor NOUN
# blev AUX
# født VERB
# i ADP
# 1937 NUM
# . PUNCT
# Mens SCONJ
# hun PRON
# voksede VERB
# op ADV
# , PUNCT
# kom VERB
# Danmark PROPN
# fri ADJ
# af ADP
# krigen NOUN
# og CCONJ
# rationeringsmærkerne NOUN
# , PUNCT
# og CCONJ
# efterhånden ADV
# fik VERB
# mange ADJ
# del NOUN
# i ADP
# de DET
# goder NOUN
# , PUNCT
# der PRON
# før ADP
# kun ADV
# var VERB
# for ADP
# de DET
# få ADJ
# . PUNCT
# Telefoner NOUN
# , PUNCT
# appelsiner NOUN
# og CCONJ
# flæskesteg NOUN
# på ADP
# søndagsbordet NOUN
# . PUNCT
#   SPACE
# Jeg PRON
# blev AUX
# født VERB
# i ADP
# 1966 NUM
# . PUNCT
#   SPACE
# Da SCONJ
# jeg PRON
# voksede VERB
# op ADV
# , PUNCT
# strømmede VERB
# kvinderne NOUN
# ud ADV
# på ADP
# arbejdsmarkedet NOUN
# . PUNCT
# Danmark PROPN
# fik VERB
# børnehaver NOUN
# , PUNCT
# plejehjem NOUN
# og CCONJ
# uddannelser NOUN
# til ADP
# de DET
# mange ADJ
# . PUNCT
# Og CCONJ
# danskerne NOUN
# fik VERB
# nye ADJ
# muligheder NOUN
# . PUNCT
# I ADP
# min DET
# årgang NOUN
# blev AUX
# vi PRON
# ikke ADV
# født VERB
# til ADP
# at PART
# følge VERB
# en DET
# bestemt ADJ
# livsbane NOUN
# . PUNCT
# Vi PRON
# fik VERB
# større ADJ
# frihed NOUN
# til ADP
# selv PRON
# at PART
# vælge VERB
# , PUNCT
# end ADP
# nogen DET
# generation NOUN
# før ADP
# os PRON
# . PUNCT
#   SPACE
# Når SCONJ
# jeg PRON
# i ADP
# dag NOUN
# ser VERB
# på ADP
# vores DET
# unge ADJ
# , PUNCT
# ser VERB
# jeg PRON
# en DET
# generation NOUN
# , PUNCT
# som PRON
# – AUX
# hvis SCONJ
# de PRON
# får VERB
# lov NOUN
# - PUNCT
# til ADP
# fulde NOUN
# forstår VERB
# at PART
# bruge VERB
# mulighederne NOUN
# . PUNCT
# I PRON
# griber VERB
# verden NOUN
# . PUNCT
# Og CCONJ
# ja INTJ
# , PUNCT
# I PRON
# kommer VERB
# også ADV
# fra ADP
# alle ADJ
# dele NOUN
# af ADP
# verden NOUN
# . PUNCT
# Unge ADJ
# med ADP
# en DET
# anden DET
# etnisk ADJ
# baggrund NOUN
# er AUX
# med ADV
# til ADP
# skabe VERB
# et DET
# samfund NOUN
# , PUNCT
# hvor ADV
# mangfoldigheden NOUN
# bliver AUX
# større ADJ
# , PUNCT
# uden ADP
# at SCONJ
# Danmark PROPN
# bliver AUX
# mindre ADJ
# . PUNCT
#   SPACE
# Fra ADP
# generation NOUN
# til ADP
# generation NOUN
# – PUNCT
# min DET
# mormors NOUN
# , PUNCT
# min DET
# mors NOUN
# , PUNCT
# min DET
# egen ADJ
# – PUNCT
# er AUX
# Danmark PROPN
# blevet AUX
# et DET
# bedre ADJ
# land NOUN
# at PART
# leve VERB
# i ADP
# . PUNCT
# Et DET
# land NOUN
# , PUNCT
# vi PRON
# kan AUX
# være AUX
# stolte ADJ
# af ADP
# . PUNCT
#   SPACE
# Og CCONJ
# vi PRON
# skal AUX
# blive VERB
# ved ADV
# med ADP
# at PART
# skabe VERB
# fremgang NOUN
# for ADP
# vores DET
# børn NOUN
# . PUNCT
# Det PRON
# er AUX
# et DET
# rimeligt ADJ
# krav NOUN
# at PART
# stille VERB
# til ADP
# os PRON
# selv PRON
# . PUNCT
#   SPACE
# Men CCONJ
# krisen NOUN
# har AUX
# gjort VERB
# det PRON
# vanskeligere ADV
# . PUNCT
# Og CCONJ
# jeg PRON
# vil AUX
# sige VERB
# det PRON
# meget ADV
# klart ADJ
# i ADP
# aften NOUN
# . PUNCT
#   SPACE
# De DET
# fede ADJ
# år NOUN
# ligger VERB
# bag ADP
# os PRON
# . PUNCT
# Vi PRON
# skal AUX
# forberede VERB
# os PRON
# på ADP
# nogle DET
# magre ADJ
# år NOUN
# . PUNCT
#   SPACE
# Den DET
# kommende VERB
# tid NOUN
# vil AUX
# kræve VERB
# meget ADJ
# af ADP
# os PRON
# . PUNCT
#           SPACE
# Meget NOUN
# er AUX
# sket VERB
# på ADP
# kort ADJ
# tid NOUN
# . PUNCT
#   SPACE
# Kan AUX
# I PRON
# huske VERB
# , PUNCT
# hvordan ADV
# det PRON
# var AUX
# for ADP
# bare ADV
# fire-fem NUM
# år NOUN
# siden ADV
# ? PUNCT
# Dengang ADV
# kunne AUX
# man PRON
# nærmest ADV
# gå VERB
# ind ADV
# fra ADP
# gaden NOUN
# og CCONJ
# få VERB
# et DET
# job NOUN
# . PUNCT
# Og CCONJ
# man PRON
# kunne AUX
# dårligt ADV
# gå VERB
# ind ADV
# i ADP
# en DET
# bank NOUN
# uden ADP
# at PART
# komme VERB
# ud ADV
# med ADP
# et DET
# lån NOUN
# . PUNCT
#   SPACE
# Nu ADV
# har AUX
# mange ADJ
# – PUNCT
# særligt ADV
# de DET
# unge ADJ
# - PUNCT
# svært ADV
# ved ADP
# at PART
# finde VERB
# arbejde NOUN
# . PUNCT
# Virksomheder NOUN
# har VERB
# svært ADV
# ved ADP
# at PART
# sælge VERB
# deres DET
# varer NOUN
# . PUNCT
# Utryghed NOUN
# og CCONJ
# bekymring NOUN
# for ADP
# fremtiden NOUN
# er AUX
# blevet AUX
# en DET
# del NOUN
# af ADP
# mange ADJ
# familiers NOUN
# hverdag NOUN
# . PUNCT
#   SPACE
# Skiftet NOUN
# fra ADP
# gode NOUN
# til ADP
# dårlige ADJ
# tider NOUN
# blev AUX
# forstærket VERB
# af ADP
# begivenheder NOUN
# ude ADV
# i ADP
# verden NOUN
# . PUNCT
# Man PRON
# førte VERB
# en DET
# kortsigtet ADJ
# og CCONJ
# slap VERB
# økonomisk ADJ
# politik NOUN
# . PUNCT
# Nogle DET
# finansfolk NOUN
# jagtede VERB
# den DET
# hurtige ADJ
# gevinst NOUN
# . PUNCT
# Der ADV
# blev AUX
# flyttet VERB
# rundt ADV
# på ADP
# investeringer NOUN
# , PUNCT
# som ADV
# om ADP
# det PRON
# var AUX
# matadorpenge NOUN
# . PUNCT
#   SPACE
# Det PRON
# var AUX
# det PRON
# ikke ADV
# . PUNCT
# Det PRON
# var AUX
# menneskers NOUN
# arbejde NOUN
# , PUNCT
# hverdag NOUN
# og CCONJ
# opsparing NOUN
# . PUNCT
#   SPACE
# Også ADV
# herhjemme ADV
# var VERB
# der ADV
# et DET
# vist ADV
# overmod NOUN
# . PUNCT
# Mange ADJ
# handlede VERB
# , PUNCT
# som ADV
# om ADP
# de DET
# gode ADJ
# tider NOUN
# bare ADV
# ville AUX
# fortsætte VERB
# og CCONJ
# fortsætte VERB
# . PUNCT
# Forbruget NOUN
# voksede VERB
# over ADP
# evne NOUN
# . PUNCT
# Og CCONJ
# boligpriserne NOUN
# tog VERB
# på ADP
# himmelflugt NOUN
# . PUNCT
#   SPACE
# Der ADV
# blev AUX
# givet VERB
# skattelettelser NOUN
# , PUNCT
# som ADP
# der ADV
# dybest ADV
# set VERB
# ikke ADV
# var VERB
# råd NOUN
# til ADP
# . PUNCT
# Og CCONJ
# man PRON
# forsømte VERB
# at PART
# ruste VERB
# Danmark PROPN
# godt ADV
# nok ADV
# til ADP
# dårligere ADJ
# tider NOUN
# . PUNCT
# Der ADV
# var VERB
# ikke ADV
# styr NOUN
# på ADP
# økonomien NOUN
# . PUNCT
#   SPACE
# Derfor ADV
# får VERB
# vi PRON
# nu ADV
# et DET
# underskud NOUN
# på ADP
# de DET
# offentlige ADJ
# finanser NOUN
# på ADP
# omkring ADP
# 100 NUM
# milliarder NOUN
# kroner NOUN
# . PUNCT
# Ja INTJ
# , PUNCT
# måske ADV
# bliver AUX
# det PRON
# endnu ADV
# større ADJ
# . PUNCT
#   SPACE
# Det PRON
# er AUX
# svimlende ADJ
# mange ADJ
# penge NOUN
# . PUNCT
#   SPACE
# Underskuddet NOUN
# betyder VERB
# , PUNCT
# at SCONJ
# vi PRON
# betaler VERB
# velfærd NOUN
# med ADP
# penge NOUN
# , PUNCT
# vi PRON
# ikke ADV
# har VERB
# . PUNCT
#   SPACE
# Det PRON
# går VERB
# ikke ADV
# i ADP
# længden NOUN
# . PUNCT
# Det PRON
# siger VERB
# sig PRON
# selv PRON
# . PUNCT
#   SPACE
# Og CCONJ
# det PRON
# går VERB
# heller ADV
# ikke ADV
# , PUNCT
# at SCONJ
# Danmark PROPN
# bliver VERB
# ved ADV
# med ADP
# at PART
# miste VERB
# konkurrencekraft NOUN
# . PUNCT
# For CCONJ
# så ADV
# flytter VERB
# virksomheder NOUN
# og CCONJ
# job NOUN
# ud ADV
# af ADP
# landet NOUN
# . PUNCT
#   SPACE
# Danske ADJ
# virksomheder NOUN
# er AUX
# nogle PRON
# af ADP
# de DET
# mest ADV
# opfindsomme ADJ
# og CCONJ
# ansvarsfulde NOUN
# i ADP
# verden NOUN
# . PUNCT
# Vi PRON
# er AUX
# et DET
# land NOUN
# , PUNCT
# hvor ADV
# små ADJ
# familievirksomheder NOUN
# vokser VERB
# sig PRON
# store ADJ
# og CCONJ
# bliver AUX
# blandt ADP
# verdens NOUN
# førende ADJ
# . PUNCT
# Vi PRON
# er AUX
# et DET
# land NOUN
# , PUNCT
# hvor ADV
# lønmodtagere NOUN
# og CCONJ
# arbejdsgivere NOUN
# har VERB
# et DET
# helt ADV
# særligt ADV
# tillidsfuldt ADJ
# samarbejde NOUN
# . PUNCT
# Et DET
# samarbejde NOUN
# , PUNCT
# som PRON
# vækker VERB
# international ADJ
# opsigt NOUN
# . PUNCT
#   SPACE
# Men CCONJ
# når SCONJ
# man PRON
# ikke ADV
# har AUX
# investeret VERB
# nok ADV
# i ADP
# uddannelse NOUN
# og CCONJ
# forskning NOUN
# . PUNCT
# Og CCONJ
# når SCONJ
# man PRON
# i ADP
# stedet NOUN
# for ADP
# en DET
# hjælpende VERB
# hånd NOUN
# kommer VERB
# med ADP
# nye ADJ
# regler NOUN
# , PUNCT
# så ADV
# bliver AUX
# det PRON
# sværere ADJ
# og CCONJ
# ikke ADV
# lettere ADJ
# at PART
# drive VERB
# virksomhed NOUN
# og CCONJ
# skabe VERB
# arbejdspladser NOUN
# i ADP
# Danmark PROPN
# . PUNCT
#   SPACE
# Vi PRON
# står VERB
# med ADP
# to NUM
# store ADJ
# udfordringer NOUN
# . PUNCT
# Vi PRON
# skal AUX
# have VERB
# styr NOUN
# på ADP
# de DET
# offentlige ADJ
# underskud NOUN
# . PUNCT
# Og CCONJ
# vores DET
# virksomheder NOUN
# skal AUX
# igen ADV
# være VERB
# blandt ADP
# de DET
# mest ADV
# konkurrencedygtige ADJ
# i ADP
# verden NOUN
# . PUNCT
#   SPACE
# På ADP
# den DET
# måde NOUN
# får VERB
# vi PRON
# en DET
# ny ADJ
# og CCONJ
# holdbar ADJ
# vækst NOUN
# , PUNCT
# og CCONJ
# vi PRON
# skaber VERB
# den DET
# rette ADJ
# grobund NOUN
# for ADP
# nye ADJ
# job NOUN
# . PUNCT
#   SPACE
# På ADP
# den DET
# måde NOUN
# får VERB
# vi PRON
# igen ADV
# pengene NOUN
# til ADP
# at PART
# passe VERB
# . PUNCT
#   SPACE
# Kan AUX
# det PRON
# lade VERB
# sig PRON
# gøre VERB
# ? PUNCT
#   SPACE
# Ja INTJ
# , PUNCT
# naturligvis ADV
# . PUNCT
# For CCONJ
# vi PRON
# har VERB
# meget ADV
# godt ADJ
# at PART
# bygge VERB
# på ADV
# i ADP
# Danmark PROPN
# . PUNCT
# Et DET
# stærkt ADJ
# fællesskab NOUN
# . PUNCT
# Vores DET
# evne NOUN
# til ADP
# at PART
# træffe VERB
# store ADJ
# beslutninger NOUN
# , PUNCT
# når SCONJ
# det PRON
# er AUX
# vanskeligt ADJ
# . PUNCT
#   SPACE
# Og CCONJ
# vi PRON
# er VERB
# i ADP
# gang NOUN
# . PUNCT
#   SPACE
# I ADP
# budgettet NOUN
# for ADP
# i ADP
# år NOUN
# bliver AUX
# der ADV
# strammet VERB
# op ADV
# på ADP
# udgifterne NOUN
# og CCONJ
# prioriteret VERB
# skarpt ADV
# . PUNCT
# Vi PRON
# holder VERB
# hånden NOUN
# under ADP
# danske ADJ
# job NOUN
# . PUNCT
# Og CCONJ
# vi PRON
# sørger VERB
# for ADP
# , PUNCT
# at SCONJ
# vi PRON
# får VERB
# flere ADJ
# indtægter NOUN
# til ADP
# vores DET
# fælles ADJ
# kasse NOUN
# , PUNCT
# så SCONJ
# vi PRON
# har VERB
# råd NOUN
# til ADP
# at PART
# investere VERB
# i ADP
# vores DET
# børn NOUN
# og CCONJ
# vores DET
# unge ADJ
# . PUNCT
#   SPACE
# Men CCONJ
# det PRON
# er AUX
# ikke ADV
# nok ADV
# . PUNCT
# Regningen NOUN
# er AUX
# ikke ADV
# betalt VERB
# . PUNCT
#   SPACE
# Og CCONJ
# krisen NOUN
# i ADP
# verden NOUN
# og CCONJ
# Europa PROPN
# er VERB
# langt ADV
# fra ADP
# slut NOUN
# . PUNCT
# Når SCONJ
# europæerne NOUN
# bliver AUX
# fattigere ADJ
# , PUNCT
# køber VERB
# de PRON
# mindre ADV
# fra ADP
# os PRON
# . PUNCT
# Det PRON
# koster VERB
# danske ADJ
# job NOUN
# . PUNCT
# Det PRON
# udfordrer VERB
# vores DET
# økonomi NOUN
# og CCONJ
# vores DET
# velfærd NOUN
# . PUNCT
#   SPACE
# I ADP
# de DET
# kommende VERB
# år NOUN
# får VERB
# vi PRON
# endnu ADV
# strammere ADJ
# budgetter NOUN
# , PUNCT
# og CCONJ
# vi PRON
# må AUX
# stille VERB
# endnu ADV
# hårdere ADJ
# krav NOUN
# til ADP
# os PRON
# selv PRON
# . PUNCT
# Vi PRON
# kommer VERB
# til ADP
# at PART
# endevende VERB
# alt ADJ
# og CCONJ
# spørge VERB
# , PUNCT
# om SCONJ
# vi PRON
# kan AUX
# gøre VERB
# det PRON
# bedre ADV
# . PUNCT
# Vi PRON
# vil AUX
# reformere VERB
# vores DET
# førtidspension NOUN
# og CCONJ
# vores DET
# kontanthjælp NOUN
# . PUNCT
# Og CCONJ
# vi PRON
# vil AUX
# reformere VERB
# vores DET
# skattesystem NOUN
# - PUNCT
# finansieret VERB
# krone NOUN
# for ADP
# krone NOUN
# . PUNCT
# Alt ADJ
# sammen ADV
# for ADP
# at PART
# få VERB
# flere ADJ
# i ADP
# arbejde NOUN
# og CCONJ
# gøre VERB
# vores DET
# økonomi NOUN
# mere ADV
# robust ADJ
# . PUNCT
#   SPACE
# Mange ADJ
# vil AUX
# opleve VERB
# forandringer NOUN
# . PUNCT
# Mange ADJ
# vil AUX
# blive AUX
# bedt VERB
# at PART
# tage VERB
# en DET
# tørn NOUN
# ekstra ADJ
# . PUNCT
#   SPACE
# Og CCONJ
# ja INTJ
# , PUNCT
# vi PRON
# vil AUX
# opleve VERB
# nedskæringer NOUN
# og CCONJ
# besparelser NOUN
# . PUNCT
#   SPACE
# I ADP
# den DET
# kommende VERB
# tid NOUN
# skal AUX
# vi PRON
# tage VERB
# beslutninger NOUN
# , PUNCT
# der PRON
# kan AUX
# måle VERB
# sig PRON
# med ADP
# de DET
# sværeste ADJ
# i ADP
# vores DET
# historie NOUN
# . PUNCT
#   SPACE
# Men CCONJ
# vi PRON
# gør VERB
# det PRON
# , PUNCT
# fordi SCONJ
# det PRON
# er AUX
# nødvendigt ADJ
# . PUNCT
# Vi PRON
# gør VERB
# det PRON
# ikke ADV
# , PUNCT
# fordi SCONJ
# vi PRON
# er AUX
# holdt VERB
# op ADV
# med ADP
# at PART
# tro VERB
# på ADP
# solidaritet NOUN
# . PUNCT
# Men CCONJ
# netop ADV
# fordi SCONJ
# vi PRON
# stadig ADV
# tror VERB
# på ADP
# solidaritet NOUN
# , PUNCT
# og CCONJ
# tror VERB
# på ADP
# at SCONJ
# vi PRON
# skal AUX
# have VERB
# alle ADJ
# med ADP
# . PUNCT
#   SPACE
# Når SCONJ
# vi PRON
# skal AUX
# træffe VERB
# svære ADJ
# beslutninger NOUN
# , PUNCT
# er AUX
# det PRON
# netop ADV
# for ADP
# at PART
# fastholde VERB
# , PUNCT
# og CCONJ
# ikke ADV
# afvikle VERB
# , PUNCT
# det DET
# Danmark PROPN
# , PUNCT
# vi PRON
# holder VERB
# af ADP
# . PUNCT
#   SPACE
# Det DET
# Danmark PROPN
# , PUNCT
# hvor ADV
# alle ADJ
# er AUX
# med ADV
# til ADP
# at PART
# skabe VERB
# fremgang NOUN
# . PUNCT
# Hvor ADV
# vi PRON
# tager VERB
# os PRON
# af ADP
# hinanden PRON
# . PUNCT
# Hvor ADV
# vi PRON
# giver VERB
# alle ADJ
# børn NOUN
# og CCONJ
# unge ADJ
# en DET
# gratis ADJ
# uddannelse NOUN
# . PUNCT
# Hvor ADV
# vi PRON
# får VERB
# god ADJ
# og CCONJ
# gratis ADJ
# behandling NOUN
# , PUNCT
# når SCONJ
# vi PRON
# er AUX
# syge ADJ
# . PUNCT
# Hvor ADV
# vi PRON
# får VERB
# hjælp NOUN
# , PUNCT
# hvis SCONJ
# vi PRON
# mister VERB
# vores DET
# arbejde NOUN
# . PUNCT
# Hvor ADV
# vi PRON
# får VERB
# en DET
# værdig ADJ
# pleje NOUN
# , PUNCT
# når SCONJ
# vi PRON
# er AUX
# ældre ADJ
# . PUNCT
#   SPACE
# Det DET
# et DET
# land NOUN
# for ADP
# de DET
# mange ADJ
# og CCONJ
# ikke ADV
# for ADP
# de DET
# få ADJ
# . PUNCT
# Det PRON
# er AUX
# et DET
# land NOUN
# baseret VERB
# på ADP
# forskellighed NOUN
# og CCONJ
# mangfoldighed NOUN
# . PUNCT
# På ADP
# menneskeværd NOUN
# . PUNCT
# På ADP
# fællesskab NOUN
# . PUNCT
#   SPACE
# Ude ADV
# i ADP
# verden NOUN
# har VERB
# vi PRON
# danskere NOUN
# ry NOUN
# for ADP
# at PART
# vise VERB
# samfundssind PROPN
# . PUNCT
# Gæster NOUN
# kommer VERB
# langvejs NOUN
# fra ADP
# for ADP
# at PART
# lære VERB
# af ADP
# vores DET
# lille ADJ
# , PUNCT
# trygge ADJ
# land NOUN
# . PUNCT
# Hvor ADV
# vi PRON
# er AUX
# mange ADJ
# , PUNCT
# der PRON
# arbejder VERB
# og CCONJ
# afleverer VERB
# halvdelen NOUN
# til ADP
# fællesskabet NOUN
# . PUNCT
# Hvor ADV
# vi PRON
# tager VERB
# os PRON
# af ADP
# hinanden PRON
# , PUNCT
# når SCONJ
# der ADV
# er VERB
# problemer NOUN
# . PUNCT
#   SPACE
# Men CCONJ
# de PRON
# undrer VERB
# sig PRON
# også ADV
# ude ADV
# i ADP
# verden NOUN
# . PUNCT
# Hvordan ADV
# kan AUX
# det PRON
# fungere VERB
# ? PUNCT
#   SPACE
# Mit DET
# bud NOUN
# er VERB
# , PUNCT
# at SCONJ
# det PRON
# kan AUX
# det PRON
# også ADV
# kun ADV
# , PUNCT
# når SCONJ
# vi PRON
# alle ADJ
# forstår VERB
# , PUNCT
# at SCONJ
# vi PRON
# skal AUX
# yde VERB
# det PRON
# , PUNCT
# vi PRON
# kan VERB
# til ADP
# fællesskabet NOUN
# . PUNCT
# Ingen PRON
# kan AUX
# bare ADV
# kræve VERB
# . PUNCT
# Enhver PRON
# må AUX
# spørge VERB
# sig PRON
# selv PRON
# . PUNCT
# Hvad PRON
# kan AUX
# jeg PRON
# gøre VERB
# ? PUNCT
#   SPACE
# Det PRON
# støder VERB
# mig PRON
# og CCONJ
# mange ADJ
# andre PRON
# , PUNCT
# hvis SCONJ
# der ADV
# er VERB
# nogen PRON
# , PUNCT
# der PRON
# ikke ADV
# yder VERB
# deres PRON
# . PUNCT
# Eller CCONJ
# ligefrem ADV
# snyder VERB
# . PUNCT
#   SPACE
# Balancen NOUN
# mellem ADP
# tryghed NOUN
# for ADP
# den DET
# enkelte ADJ
# og CCONJ
# forpligtigelsen NOUN
# til ADP
# at PART
# bidrage VERB
# er AUX
# selve ADJ
# grundlaget NOUN
# for ADP
# vores DET
# velfærdssamfund NOUN
# . PUNCT
#   SPACE
# Og CCONJ
# den DET
# balance NOUN
# er AUX
# truet VERB
# , PUNCT
# når SCONJ
# unge ADJ
# , PUNCT
# raske ADJ
# mennesker NOUN
# kan AUX
# være VERB
# på ADP
# offentlig ADJ
# forsørgelse NOUN
# år NOUN
# efter ADP
# år NOUN
# . PUNCT
# Så ADV
# har VERB
# både ADV
# den DET
# enkelte ADJ
# og CCONJ
# samfundet NOUN
# svigtet VERB
# . PUNCT
# Det PRON
# er AUX
# ikke ADV
# rimeligt ADJ
# . PUNCT
#   SPACE
# Balancen NOUN
# er AUX
# truet VERB
# , PUNCT
# hver PRON
# gang NOUN
# nogen PRON
# får VERB
# bygget VERB
# en DET
# garage NOUN
# eller CCONJ
# lagt VERB
# nyt ADJ
# tag NOUN
# på ADP
# huset NOUN
# uden ADP
# regning NOUN
# og CCONJ
# moms ADV
# . PUNCT
# Det PRON
# er AUX
# ikke ADV
# rimeligt ADJ
# . PUNCT
#   SPACE
# Og CCONJ
# hvis SCONJ
# en DET
# virksomhed NOUN
# beder VERB
# sine DET
# medarbejdere NOUN
# om ADP
# at PART
# holde VERB
# igen ADV
# med ADP
# lønkrav NOUN
# , PUNCT
# så ADV
# er AUX
# det PRON
# også ADV
# rimeligt ADJ
# , PUNCT
# at SCONJ
# det PRON
# gælder VERB
# for ADP
# alle ADJ
# . PUNCT
# Også ADV
# på ADP
# chefgangen NOUN
# . PUNCT
# Alle ADJ
# skal AUX
# bidrage VERB
# . PUNCT
# Der ADV
# er VERB
# ingen DET
# fribilletter NOUN
# . PUNCT
#   SPACE
# Og CCONJ
# jeg PRON
# tror VERB
# på ADP
# , PUNCT
# at SCONJ
# langt ADV
# de DET
# fleste ADJ
# af ADP
# os PRON
# gerne ADV
# vil AUX
# være AUX
# med ADV
# . PUNCT
# De DET
# fleste ADJ
# vil AUX
# gerne ADV
# tage VERB
# ansvar NOUN
# . PUNCT
#   SPACE
# Jeg PRON
# har VERB
# dyb ADJ
# respekt NOUN
# for ADP
# mennesker NOUN
# , PUNCT
# der PRON
# hver PRON
# dag NOUN
# går VERB
# på ADP
# arbejde NOUN
# og CCONJ
# forsørger VERB
# sig PRON
# selv PRON
# og CCONJ
# deres DET
# familie NOUN
# . PUNCT
# Danmark PROPN
# er AUX
# bygget VERB
# af ADP
# hårdtarbejdende VERB
# mænd NOUN
# og CCONJ
# kvinder NOUN
# . PUNCT
#   SPACE
# Men CCONJ
# den DET
# respekt NOUN
# må AUX
# aldrig ADV
# få VERB
# os PRON
# til ADP
# at PART
# miste VERB
# respekten NOUN
# for ADP
# eller CCONJ
# tale VERB
# nedsættende VERB
# om ADP
# dem PRON
# , PUNCT
# der PRON
# af ADP
# en DET
# eller CCONJ
# anden PRON
# grund NOUN
# ikke ADV
# kan AUX
# klare VERB
# sig PRON
# selv PRON
# . PUNCT
#   SPACE
# I ADP
# de DET
# seneste ADJ
# år NOUN
# har AUX
# flere ADJ
# tusinde NOUN
# danskere NOUN
# mistet VERB
# deres DET
# arbejde NOUN
# . PUNCT
# Og CCONJ
# i ADP
# det DET
# nye ADJ
# år NOUN
# vil AUX
# de PRON
# desværre ADV
# få VERB
# følgeskab NOUN
# af ADP
# flere ADJ
# . PUNCT
# Det PRON
# er AUX
# ulykkeligt ADJ
# for ADP
# den DET
# enkelte ADJ
# og CCONJ
# for ADP
# Danmark PROPN
# . PUNCT
#   SPACE
# Vi PRON
# skal AUX
# gøre VERB
# , PUNCT
# hvad PRON
# vi PRON
# kan VERB
# , PUNCT
# for ADP
# at SCONJ
# færrest ADJ
# muligt ADV
# bliver AUX
# ledige ADJ
# . PUNCT
# Derfor ADV
# kick-starter VERB
# regeringen NOUN
# dansk ADJ
# økonomi NOUN
# . PUNCT
# Vi PRON
# investerer VERB
# milliarder NOUN
# i ADP
# børnehaver NOUN
# , PUNCT
# veje NOUN
# og CCONJ
# arbejdspladser NOUN
# over ADP
# hele ADJ
# landet NOUN
# . PUNCT
# På ADP
# den DET
# måde NOUN
# kommer VERB
# der ADV
# job NOUN
# allerede ADV
# i ADP
# år NOUN
# , PUNCT
# som PRON
# ellers ADV
# ikke ADV
# ville AUX
# have AUX
# været VERB
# der ADV
# . PUNCT
#   SPACE
# Men CCONJ
# det PRON
# gør VERB
# det PRON
# ikke ADV
# mindre ADV
# hårdt ADJ
# for ADP
# den DET
# enkelte ADJ
# , PUNCT
# der PRON
# skriver VERB
# ansøgning NOUN
# efter ADP
# ansøgning NOUN
# og CCONJ
# får VERB
# afslag NOUN
# på ADP
# afslag NOUN
# . PUNCT
#   SPACE
# I ADP
# december NOUN
# var AUX
# jeg PRON
# i ADP
# Aalborg PROPN
# . PUNCT
# Her ADV
# mødte VERB
# jeg PRON
# Søren PROPN
# . PUNCT
# Han PRON
# er AUX
# 60 NUM
# år NOUN
# . PUNCT
# Han PRON
# fortalte VERB
# mig PRON
# , PUNCT
# at SCONJ
# han PRON
# var AUX
# blevet AUX
# fyret VERB
# efter ADP
# at PART
# have AUX
# arbejdet VERB
# mere ADV
# end ADP
# 30 NUM
# år NOUN
# som ADP
# sælger NOUN
# . PUNCT
# Firmaets NOUN
# omsætning NOUN
# var AUX
# faldet VERB
# på ADP
# grund NOUN
# af ADP
# krisen NOUN
# . PUNCT
# Det PRON
# er AUX
# to NUM
# år NOUN
# siden ADV
# . PUNCT
# Søren PROPN
# fortalte VERB
# mig PRON
# , PUNCT
# at SCONJ
# han PRON
# har AUX
# søgt VERB
# stort ADV
# set VERB
# alt ADJ
# , PUNCT
# der ADV
# er VERB
# at PART
# søge VERB
# i ADP
# Midt- NOUN
# og CCONJ
# Nordjylland PROPN
# . PUNCT
# Fra ADP
# receptionist NOUN
# på ADP
# kommunen NOUN
# til ADP
# chauffør NOUN
# for ADP
# en DET
# slagter NOUN
# . PUNCT
# Men CCONJ
# uden ADP
# held NOUN
# . PUNCT
#   SPACE
# Og CCONJ
# jo ADV
# . PUNCT
# Vi PRON
# skal AUX
# stille VERB
# krav NOUN
# til ADP
# hinanden PRON
# . PUNCT
# Men CCONJ
# vi PRON
# må AUX
# samtidig ADV
# forstå VERB
# , PUNCT
# også ADV
# med ADP
# hjertet NOUN
# , PUNCT
# at SCONJ
# alle ADJ
# kan AUX
# komme VERB
# i ADP
# en DET
# situation NOUN
# , PUNCT
# hvor ADV
# der ADV
# er VERB
# brug NOUN
# for ADP
# hjælp NOUN
# . PUNCT
#   SPACE
# Krisen NOUN
# har AUX
# gjort VERB
# Danmark PROPN
# fattigere ADV
# . PUNCT
# Men CCONJ
# vi PRON
# er AUX
# først ADV
# for ADP
# alvor NOUN
# et DET
# fattigere ADJ
# land NOUN
# , PUNCT
# når SCONJ
# vi PRON
# ikke ADV
# længere ADV
# forstår VERB
# dem PRON
# , PUNCT
# som PRON
# har VERB
# brug NOUN
# for ADP
# hjælp NOUN
# . PUNCT
#   SPACE
# Det PRON
# må AUX
# ikke ADV
# ske VERB
# . PUNCT
# Og CCONJ
# med ADP
# fælles ADJ
# anstrengelse NOUN
# vil AUX
# det PRON
# ikke ADV
# ske VERB
# . PUNCT
#          SPACE
# Der ADV
# er VERB
# en DET
# gruppe NOUN
# danskere NOUN
# , PUNCT
# som PRON
# vi PRON
# skylder VERB
# en DET
# særlig ADJ
# hilsen NOUN
# her ADV
# i ADP
# aften NOUN
# . PUNCT
# Det PRON
# er AUX
# en DET
# gruppe NOUN
# , PUNCT
# som PRON
# har AUX
# påtaget VERB
# sig PRON
# et DET
# kæmpe ADJ
# ansvar NOUN
# . PUNCT
#   SPACE
# De DET
# danske ADJ
# soldater NOUN
# i ADP
# Afghanistan PROPN
# . PUNCT
# Jeg PRON
# har AUX
# besøgt VERB
# jer PRON
# og CCONJ
# set VERB
# , PUNCT
# hvor ADV
# flot ADV
# I ADP
# løfter NOUN
# jeres DET
# opgave NOUN
# . PUNCT
# Det PRON
# er AUX
# jeg PRON
# stolt ADJ
# af ADP
# . PUNCT
# Det PRON
# er AUX
# hele ADJ
# Danmark PROPN
# stolt ADJ
# af ADP
# . PUNCT
#   SPACE
# Vores DET
# indsats NOUN
# i ADP
# Afghanistan PROPN
# har AUX
# kostet VERB
# liv NOUN
# . PUNCT
# I ADP
# aften NOUN
# går VERB
# mine DET
# tanker NOUN
# til ADP
# jer PRON
# , PUNCT
# der PRON
# har AUX
# mistet VERB
# en PRON
# af ADP
# jeres DET
# kære ADJ
# . PUNCT
#   SPACE
# Æret NOUN
# være AUX
# deres DET
# minde NOUN
# . PUNCT
#   SPACE
# Når SCONJ
# jeg PRON
# møder VERB
# folk NOUN
# i ADP
# udlandet NOUN
# , PUNCT
# så ADV
# nævner VERB
# de PRON
# meget ADV
# ofte ADV
# Danmarks PROPN
# indsats NOUN
# i ADP
# Afghanistan PROPN
# og CCONJ
# vores DET
# indsats NOUN
# for ADP
# at PART
# beskytte VERB
# befolkningen NOUN
# i ADP
# Libyen PROPN
# . PUNCT
# Den DET
# indsats NOUN
# vil AUX
# blive AUX
# husket VERB
# i ADP
# mange ADJ
# år NOUN
# . PUNCT
#   SPACE
# De DET
# skarpe ADJ
# missioner NOUN
# er AUX
# vigtige ADJ
# . PUNCT
# Men CCONJ
# Danmark PROPN
# gør VERB
# mere ADJ
# end ADP
# det PRON
# . PUNCT
# Meget ADV
# mere ADJ
# . PUNCT
#   SPACE
# Vi PRON
# er VERB
# blandt ADP
# de DET
# fem NUM
# lande NOUN
# i ADP
# verden NOUN
# , PUNCT
# der PRON
# yder VERB
# mest ADV
# i ADP
# kampen NOUN
# mod ADP
# fattigdom NOUN
# – AUX
# og CCONJ
# vi PRON
# vil AUX
# gøre VERB
# endnu ADV
# mere ADJ
# i ADP
# det DET
# nye ADJ
# år NOUN
# . PUNCT
# Vi PRON
# står VERB
# på ADP
# demokratiets NOUN
# side NOUN
# – PUNCT
# senest ADV
# under ADP
# det DET
# arabiske ADJ
# forår NOUN
# . PUNCT
# Vi PRON
# bidrager VERB
# til ADP
# en DET
# bæredygtig ADJ
# udvikling NOUN
# – PUNCT
# også ADV
# i ADP
# de DET
# fattige ADJ
# lande NOUN
# . PUNCT
#   SPACE
# Danmark PROPN
# er AUX
# anerkendt VERB
# for ADP
# vores DET
# brede ADJ
# indsats NOUN
# og CCONJ
# for ADP
# at PART
# påtage VERB
# os PRON
# et DET
# ansvar NOUN
# , PUNCT
# der PRON
# rækker VERB
# langt ADV
# ud ADV
# over ADP
# vores DET
# grænser NOUN
# og CCONJ
# langt ADV
# ud ADV
# over ADP
# vores DET
# størrelse NOUN
# . PUNCT
# Og CCONJ
# det PRON
# giver VERB
# respekt NOUN
# ude ADV
# i ADP
# verden NOUN
# . PUNCT
# Danmark PROPN
# nyder VERB
# høj ADJ
# anseelse NOUN
# . PUNCT
# Og CCONJ
# den DET
# anseelse NOUN
# har AUX
# vi PRON
# alle ADJ
# lod NOUN
# og CCONJ
# del NOUN
# i ADP
# . PUNCT
#   SPACE
# Derfor ADV
# er VERB
# der ADV
# også ADV
# store ADJ
# forventninger NOUN
# til ADP
# Danmark PROPN
# , PUNCT
# når SCONJ
# vi PRON
# i ADP
# dag NOUN
# den DET
# 1. ADJ
# januar NOUN
# overtager VERB
# formandskabet NOUN
# for ADP
# EU PROPN
# . PUNCT
#   SPACE
# Danmark PROPN
# skal AUX
# lede VERB
# EU PROPN
# på ADP
# et DET
# meget ADV
# vanskeligt ADJ
# tidspunkt NOUN
# . PUNCT
# Der ADV
# ligger VERB
# store ADJ
# opgaver NOUN
# foran ADP
# os PRON
# . PUNCT
# Og CCONJ
# dem PRON
# vil AUX
# vi PRON
# arbejde VERB
# hårdt ADV
# på ADP
# at PART
# løfte VERB
# . PUNCT
# Vi PRON
# vil AUX
# yde VERB
# vores DET
# til ADP
# , PUNCT
# at SCONJ
# de DET
# europæiske ADJ
# lande NOUN
# sammen ADV
# kan AUX
# få VERB
# styr NOUN
# på ADP
# økonomien NOUN
# og CCONJ
# gang NOUN
# i ADP
# væksten NOUN
# igen ADV
# . PUNCT
# Det PRON
# er AUX
# det PRON
# , PUNCT
# der PRON
# skal AUX
# til ADV
# , PUNCT
# for CCONJ
# igen ADV
# at PART
# skabe VERB
# job NOUN
# i ADP
# Europa PROPN
# . PUNCT
#   SPACE
# Alt ADJ
# , PUNCT
# hvad PRON
# der ADV
# sker VERB
# i ADP
# Europa PROPN
# , PUNCT
# påvirker VERB
# os PRON
# herhjemme ADV
# . PUNCT
# Derfor ADV
# skal AUX
# vi PRON
# bruge VERB
# hver DET
# en DET
# mulighed NOUN
# til ADP
# at PART
# påvirke VERB
# det PRON
# , PUNCT
# der PRON
# sker VERB
# i ADP
# Europa PROPN
# . PUNCT
# Det PRON
# er VERB
# i ADP
# Danmarks PROPN
# og CCONJ
# danskernes NOUN
# klare ADJ
# interesse NOUN
# . PUNCT
#   SPACE
# Det DET
# næste ADJ
# halve ADJ
# år NOUN
# har VERB
# vi PRON
# en DET
# mulighed NOUN
# for ADP
# at PART
# skubbe VERB
# Europa PROPN
# et DET
# lille ADJ
# , PUNCT
# men CCONJ
# vigtigt ADJ
# , PUNCT
# skridt NOUN
# i ADP
# den DET
# rigtige ADJ
# retning NOUN
# . PUNCT
# Den DET
# mulighed NOUN
# skal AUX
# vi PRON
# bruge VERB
# . PUNCT
#          SPACE
# 2012 NUM
# bliver AUX
# ikke ADV
# året NOUN
# , PUNCT
# hvor ADV
# vi PRON
# får VERB
# løst VERB
# alle ADJ
# vores DET
# problemer NOUN
# . PUNCT
#   SPACE
# Men CCONJ
# det PRON
# kan AUX
# blive AUX
# et DET
# år NOUN
# , PUNCT
# hvor ADV
# vi PRON
# igen ADV
# finder VERB
# ind ADV
# til ADP
# den DET
# kerne NOUN
# af ADP
# samarbejde NOUN
# , PUNCT
# solidaritet NOUN
# og CCONJ
# samfundssind NOUN
# , PUNCT
# som PRON
# har AUX
# gjort VERB
# Danmark PROPN
# til ADP
# et DET
# fantastisk ADJ
# land NOUN
# . PUNCT
#   SPACE
# Året NOUN
# , PUNCT
# hvor ADV
# vi PRON
# træffer VERB
# svære ADJ
# , PUNCT
# men CCONJ
# nødvendige ADJ
# beslutninger NOUN
# . PUNCT
#   SPACE
# Vi PRON
# skal AUX
# aflevere VERB
# et DET
# endnu ADV
# bedre ADJ
# Danmark PROPN
# til ADP
# den DET
# næste ADJ
# generation NOUN
# . PUNCT
# Vores DET
# børn NOUN
# skal AUX
# arve VERB
# et DET
# land NOUN
# med ADP
# fremgang NOUN
# , PUNCT
# tryghed NOUN
# og CCONJ
# muligheder NOUN
# for ADP
# alle ADJ
# . PUNCT
#   SPACE
# Godt ADJ
# nytår NOUN
# ! PUNCT

# %% [markdown]
# ## Substantiver
# Vi kan lave en en liste over substantiver ved at sortere efter POS-tagget "NOUN".
#
# Kodesekvensen nedenfor indeholde ene kendte elementer.

# %%
subst_1 = []
for s in sents1: # loop 1
    for w in s:  # loop 2
        if w.pos_ == "NOUN": # condition
                subst_1.append(w.text) # output

print(len(subst_1))

print(sorted(set(subst_1)))
# Out:
# 388
# ['Balancen', 'Demokratiet', 'Firmaets', 'Forbruget', 'Generation', 'Gæster', 'Krisen', 'Meget', 'Midt-', 'Regningen', 'Skiftet', 'Telefoner', 'Underskuddet', 'Utryghed', 'Virksomheder', 'afslag', 'aften', 'alvor', 'anseelse', 'anstrengelse', 'ansvar', 'ansvarsfulde', 'ansøgning', 'appelsiner', 'arbejde', 'arbejdsgivere', 'arbejdsmarkedet', 'arbejdspladser', 'baggrund', 'balance', 'bank', 'befolkningen', 'begivenheder', 'behandling', 'behold', 'bekymring', 'beslutninger', 'besparelser', 'boligpriserne', 'brug', 'bud', 'budgetter', 'budgettet', 'børn', 'børnehaver', 'chauffør', 'chefgangen', 'dag', 'danskere', 'danskerne', 'danskernes', 'december', 'del', 'dele', 'demokratiets', 'europæerne', 'evne', 'familie', 'familiers', 'familievirksomheder', 'fattigdom', 'finanser', 'finansfolk', 'flæskesteg', 'folk', 'forandringer', 'formandskabet', 'forpligtigelsen', 'forskellighed', 'forskning', 'forsørgelse', 'forventninger', 'forår', 'fremgang', 'fremskridt', 'fremtiden', 'fribilletter', 'frihed', 'fulde', 'fællesskab', 'fællesskabet', 'følgeskab', 'førtidspension', 'gaden', 'gang', 'garage', 'generation', 'gevinst', 'gode', 'goder', 'grobund', 'grund', 'grundlaget', 'gruppe', 'grænser', 'halvdelen', 'held', 'hilsen', 'himmelflugt', 'historie', 'hjertet', 'hjælp', 'huset', 'hverdag', 'hånd', 'hånden', 'indsats', 'indtægter', 'interesse', 'investeringer', 'januar', 'job', 'kampen', 'kasse', 'kerne', 'kommunen', 'konkurrencekraft', 'kontanthjælp', 'krav', 'krigen', 'krisen', 'krisetid', 'krone', 'kroner', 'kvinder', 'kvinderne', 'land', 'lande', 'landet', 'langvejs', 'liv', 'livsbane', 'lod', 'lov', 'lån', 'længden', 'løfter', 'lønkrav', 'lønmodtagere', 'mangfoldighed', 'mangfoldigheden', 'matadorpenge', 'medarbejdere', 'mennesker', 'menneskers', 'menneskeværd', 'milliarder', 'minde', 'missioner', 'mor', 'mormor', 'mormors', 'mors', 'mulighed', 'muligheder', 'mulighederne', 'måde', 'mål', 'måneder', 'mænd', 'nedskæringer', 'nytår', 'omsorg', 'omsætning', 'opgave', 'opgaver', 'opsigt', 'opsparing', 'ordentlighed', 'overmod', 'penge', 'pengene', 'pleje', 'plejehjem', 'politik', 'problemer', 'problemerne', 'rationeringsmærkerne', 'receptionist', 'regering', 'regeringen', 'regler', 'regning', 'respekt', 'respekten', 'retning', 'ry', 'råd', 'samarbejde', 'samfund', 'samfundet', 'samfundssind', 'side', 'situation', 'skattelettelser', 'skattesystem', 'skridt', 'slagter', 'slut', 'soldater', 'solidaritet', 'stedet', 'stemmeret', 'styr', 'størrelse', 'sælger', 'søndagsbordet', 'tag', 'tanker', 'tid', 'tider', 'tidspunkt', 'tjenestefolk', 'tryghed', 'tusinde', 'tørn', 'uddannelse', 'uddannelser', 'udfordringer', 'udgifterne', 'udlandet', 'udvikling', 'udviklingen', 'underskud', 'varer', 'veje', 'velfærd', 'velfærdssamfund', 'velstand', 'verden', 'verdens', 'virksomhed', 'virksomheder', 'vækst', 'væksten', 'Året', 'Æret', 'år', 'året', 'årgang', 'øjnene', 'økonomi', 'økonomien']

# %% [markdown]
# # Opgave 4
# **Omskriv** kodesekvensen ovenfor, så I i stedet for et `for loop` laver en sorteret liste over substantiver ved hjælp af `list comprehension`. I kan bruge koden for NER-listerne som inspiration.
#
# **Tip:** rækkefølgen skal være `[output loop1 loop2 condition]`

# %% [markdown]
# # Opgave 5

# %% [markdown]
# **Lav** tilsvarende lister for **verber** og **adjektiver**.

# %% [markdown]
# # 4. WordCloud
# Der en mange måder at visualisere tekstdata på. En måderne er at lave en en `word cloud`.
#
# I kan læse mere om mulighederne her: https://github.com/amueller/word_cloud
#
# For at lave en word-cloud skal vi først importere WordCloud-modulet.
#
# Hvis I ikke har modulet installeret kan i køre følgende linje i terminalen:
#
# `conda install -c conda-forge wordcloud`
#
# **Importér** WordCloud-modulet.

# %%
from wordcloud import WordCloud # der er flere undermoduler i wordcloud - derfor 'from'-kommandoen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10412/3228239330.py in <module>
# ----> 1 from wordcloud import WordCloud # der er flere undermoduler i wordcloud - derfor 'from'-kommandoen
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# WordCloud tager hele strenge som input. Vi skal derfor først have samlet vores liste af substantiver til en samlet `string`. Dette gøres med `.join()`-kommandoen.

# %%
sub_string_1 = " ".join(subst_1)

# %% [markdown]
# Herefter kan vi lave en word cloud over listen af substantiver. Koden er relativt overskuelig og let at læse.
#
# **Afprøv** sekvensen nedenfor. **Læs** koden og **diskutér**, hvad de enkelte dele betyder.

# %%
cloud_sub_1 = WordCloud(width = 1200, height = 800,
                background_color ='white',
                max_words=20,
                min_font_size = 10).generate(sub_string_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10412/842734326.py in <module>
# ----> 1 cloud_sub_1 = WordCloud(width = 1200, height = 800,
#       2                 background_color ='white',
#       3                 max_words=20,
#       4                 min_font_size = 10).generate(sub_string_1)
#
# NameError: name 'WordCloud' is not defined

# %%
plt.imshow(cloud_sub_1, interpolation='bilinear')

# %% [markdown]
# # Opgave 6
# Hvis I har tid tilovers skal kan I lave substantiv-lister og word-clouds for nogle af de andre taler.
